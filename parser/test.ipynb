# %%
from models import ApartmentModel
# %load_ext autoreload
# %autoreload 2

# %%
from functions import select_relevant_apartments

# %%
select_relevant_apartments()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 select_relevant_apartments()
#
# NameError: name 'select_relevant_apartments' is not defined
